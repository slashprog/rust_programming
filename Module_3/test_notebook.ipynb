// %% [markdown]
// To work with Rust in Jupyter notebook:
//
// Install evcxr (Evaluation Context for Rust)
//
// https://github.com/evcxr/evcxr/blob/main/evcxr_jupyter/README.md

// %%
println!("Hello, world!");
// Out:
// Hello, world!

// %%
let s :String = String::from("Hello, Rust!");
println!("{}", s);
// Out:
// Hello, Rust!

// %%
let s :String = String::from("hello");
let bytes: Vec<u8> = s.into_bytes();
println!("{:?}", bytes);
println!("Type of bytes: {}", std::any::type_name_of_val(&bytes));
// Out:
// [104, 101, 108, 108, 111]
// Type of bytes: alloc::vec::Vec<u8>
